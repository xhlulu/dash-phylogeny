# %% [markdown]
# ## Plotly rectangular phylogenetic tree for Zika Virus ##

# %%
from Bio import Phylo
import pandas as pd
from plotly.grid_objs import Column, Grid

# %%
from plotly.offline import download_plotlyjs, init_notebook_mode,  iplot, plot
init_notebook_mode(connected=True)
# Out:
# <script>requirejs.config({paths: { 'plotly': ['https://cdn.plot.ly/plotly-latest.min']},});if(!window.Plotly) {{require(['plotly'],function(plotly) {window.Plotly=plotly;});}}</script>

# %%
tree = Phylo.read('nextstrain_zika_tree.new', "newick")

# %%
print(tree)
# Out:
# Tree(rooted=False, weight=1.0)
#     Clade(branch_length=0.0, name='NODE_0000385')
#         Clade(branch_length=6.555195508771621e-09, name='NODE_0000349')
#             Clade(branch_length=0.005791682797542086, name='NIID123/2016')
#             Clade(branch_length=0.004384661968494351, name='NODE_0000355')
#                 Clade(branch_length=0.0005576851603132952, name='ZKA_16_097')
#                 Clade(branch_length=0.0006507515846834455, name='SG_108')
#                 Clade(branch_length=9.291026105521637e-05, name='NODE_0000363')
#                     Clade(branch_length=6.555195508801959e-09, name='SG_037')
#                     Clade(branch_length=9.291097893227018e-05, name='NODE_0000365')
#                         Clade(branch_length=0.0003717753998666298, name='SG_046')
#                         Clade(branch_length=0.00018585767239837157, name='SG_027')
#                 Clade(branch_length=6.555195508801959e-09, name='NODE_0000483')
#                     Clade(branch_length=9.290947432497292e-05, name='NODE_0000380')
#                         Clade(branch_length=0.00027877872499755627, name='SG_109')
#                         Clade(branch_length=9.290947433932863e-05, name='SG_111')
#                     Clade(branch_length=6.555195508801959e-09, name='NODE_0000484')
#                         Clade(branch_length=0.00018583530356231556, name='SG_063')
#                         Clade(branch_length=6.555195508801959e-09, name='NODE_0000485')
#                             Clade(branch_length=9.290947432497292e-05, name='NODE_0000373')
#                                 Clade(branch_length=6.555195508801959e-09, name='SG_105')
#                                 Clade(branch_length=9.290947433932863e-05, name='NODE_0000374')
#                                     Clade(branch_length=9.291132535257929e-05, name='SG_020')
#                                     Clade(branch_length=6.555195508801959e-09, name='SG_016')
#                             Clade(branch_length=6.555195508801959e-09, name='NODE_0000486')
#                                 Clade(branch_length=9.291034462908989e-05, name='NODE_0000358')
#                                     Clade(branch_length=0.00018583704705949639, name='SG_013')
#                                     Clade(branch_length=6.555195508801959e-09, name='SG_061')
#                                 Clade(branch_length=6.555195508801959e-09, name='NODE_0000487')
#                                     Clade(branch_length=9.292894037943745e-05, name='NODE_0000359')
#                                         Clade(branch_length=9.290533770798474e-05, name='SG_008')
#                                         Clade(branch_length=6.555195508801959e-09, name='NODE_0000488')
#                                             Clade(branch_length=6.555195508801959e-09, name='SG_005')
#                                             Clade(branch_length=6.555195508801959e-09, name='NODE_0000489')
#                                                 Clade(branch_length=6.555195508801959e-09, name='SG_097')
#                                                 Clade(branch_length=6.555195508801959e-09, name='SG_014')
#                                     Clade(branch_length=6.555195508801959e-09, name='NODE_0000490')
#                                         Clade(branch_length=9.290962685398405e-05, name='SG_009')
#                                         Clade(branch_length=6.555195508801959e-09, name='NODE_0000386')
#                                             Clade(branch_length=9.291369890522799e-05, name='SG_025')
#                                             Clade(branch_length=6.555195508801959e-09, name='NODE_0000387')
#                                                 Clade(branch_length=6.555195508801959e-09, name='SG_102')
#                                                 Clade(branch_length=6.555195508801959e-09, name='NODE_0000388')
#                                                     Clade(branch_length=6.555195508801959e-09, name='SG_095')
#                                                     Clade(branch_length=6.555195508801959e-09, name='NODE_0000389')
#                                                         Clade(branch_length=6.555195508801959e-09, name='SG_033')
#                                                         Clade(branch_length=6.555195508801959e-09, name='NODE_0000390')
#                                                             Clade(branch_length=6.555195508801959e-09, name='SG_100')
#                                                             Clade(branch_length=6.555195508801959e-09, name='NODE_0000391')
#                                                                 Clade(branch_length=6.555195508801959e-09, name='SG_041')
#                                                                 Clade(branch_length=6.555195508801959e-09, name='NODE_0000392')
#                                                                     Clade(branch_length=6.555195508801959e-09, name='SG_090')
#                                                                     Clade(branch_length=6.555195508801959e-09, name='NODE_0000393')
#                                                                         Clade(branch_length=6.555195508801959e-09, name='SG_073')
#                                                                         Clade(branch_length=6.555195508801959e-09, name='SG_039')
#         Clade(branch_length=0.0012088403113641886, name='NODE_0000348')
#             Clade(branch_length=0.0012088490956621734, name='1_0038_PF')
#             Clade(branch_length=9.289304552495526e-05, name='NODE_0000333')
#                 Clade(branch_length=0.0006506373034487578, name='1_0111_PF')
#                 Clade(branch_length=0.00046467257620650716, name='1_0030_PF')
#                 Clade(branch_length=6.555195508801959e-09, name='NODE_0000394')
#                     Clade(branch_length=9.289296201114481e-05, name='NODE_0000328')
#                         Clade(branch_length=0.0004646097457009369, name='1_0035_PF')
#                         Clade(branch_length=6.555195508801959e-09, name='NODE_0000395')
#                             Clade(branch_length=0.0002787524309802113, name='H/PF/2013')
#                             Clade(branch_length=6.555195508801959e-09, name='NODE_0000396')
#                                 Clade(branch_length=0.0003716602024022779, name='1_0080_PF')
#                                 Clade(branch_length=0.00018579890963822264, name='1_0087_PF')
#                     Clade(branch_length=0.0006505790208789167, name='NODE_0000334')
#                         Clade(branch_length=9.289454960175565e-05, name='NODE_0000335')
#                             Clade(branch_length=0.002980689664419534, name='Chiba/S36/2016')
#                             Clade(branch_length=0.000743601807765319, name='TS17_2016')
#                         Clade(branch_length=0.0013952080105308394, name='NODE_0000336')
#                             Clade(branch_length=6.555195508801959e-09, name='ZJ02')
#                             Clade(branch_length=9.290465075146226e-05, name='NODE_0000337')
#                                 Clade(branch_length=0.0003717146107576415, name='ZJ03')
#                                 Clade(branch_length=0.0002787625279460559, name='NODE_0000338')
#                                     Clade(branch_length=9.290416913719339e-05, name='Zhejiang04')
#                                     Clade(branch_length=9.290480330151384e-05, name='NODE_0000339')
#                                         Clade(branch_length=6.555195508801959e-09, name='CN/SZ02/2016')
#                                         Clade(branch_length=0.0001858240637959709, name='SZ_WIV01')
#                                         Clade(branch_length=9.291509912518229e-05, name='NODE_0000340')
#                                             Clade(branch_length=9.291102706754546e-05, name='ZJ04')
#                                             Clade(branch_length=9.291174485968803e-05, name='ZJ01')
#                                             Clade(branch_length=9.291087448795934e-05, name='SZ01/2016/China')
#                                         Clade(branch_length=0.0001858240637959709, name='NODE_0000344')
#                                             Clade(branch_length=6.555195508801959e-09, name='SMGC_1')
#                                             Clade(branch_length=6.555195508801959e-09, name='NODE_0000397')
#                                                 Clade(branch_length=0.00037178660802780414, name='NODE_0000347')
#                                                     Clade(branch_length=6.555195508801959e-09, name='_CCMU01/2016')
#                                                     Clade(branch_length=6.555195508801959e-09, name='SY01_2016')
#                                                 Clade(branch_length=6.555195508801959e-09, name='NODE_0000398')
#                                                     Clade(branch_length=6.555195508801959e-09, name='Z16006')
#                                                     Clade(branch_length=6.555195508801959e-09, name='ZKC2/2016')
#                 Clade(branch_length=9.289232800203462e-05, name='NODE_0000323')
#                     Clade(branch_length=0.0008368969403068742, name='1_0016_PF')
#                     Clade(branch_length=0.0005575825675959499, name='1_0015_PF')
#                     Clade(branch_length=9.289154154413777e-05, name='NODE_0000325')
#                         Clade(branch_length=0.00037165635690489837, name='1_0134_PF')
#                         Clade(branch_length=9.289145800194486e-05, name='1_0199_PF')
#                     Clade(branch_length=9.289169403947162e-05, name='NODE_0000322')
#                         Clade(branch_length=0.00018579811238057906, name='PF13/251013_18')
#                         Clade(branch_length=0.00018579684234499043, name='1_0181_PF')
#                     Clade(branch_length=0.0002787250504805738, name='NODE_0000320')
#                         Clade(branch_length=0.0003716893261028857, name='1_0049_PF')
#                         Clade(branch_length=0.00027872788187560107, name='1_0117_PF')
#                         Clade(branch_length=0.00027872788187560107, name='NODE_0000309')
#                             Clade(branch_length=0.0005576245900686698, name='NODE_0000310')
#                                 Clade(branch_length=0.0008366915232222256, name='Haiti/1/2016')
#                                 Clade(branch_length=0.0002787175141836513, name='NODE_0000311')
#                                     Clade(branch_length=6.555195508801959e-09, name='Haiti/1225/2014')
#                                     Clade(branch_length=0.00046459957337844195, name='NODE_0000312')
#                                         Clade(branch_length=6.555195508801959e-09, name='SPH2015')
#                                         Clade(branch_length=9.289844765418944e-05, name='NODE_0000313')
#                                             Clade(branch_length=6.555195508801959e-09, name='V17829')
#                                             Clade(branch_length=0.00018580065237958814, name='PE243')
#                                             Clade(branch_length=0.000278733601777451, name='Brazil/PE243/2015')
#                                             Clade(branch_length=0.0012091099264573816, name='NODE_0000316')
#                                                 Clade(branch_length=9.291095298443255e-05, name='Brazil/2016/ZBRC25')
#                                                 Clade(branch_length=9.291103653919375e-05, name='NODE_0000317')
#                                                     Clade(branch_length=6.555195508801959e-09, name='ZBRC13')
#                                                     Clade(branch_length=6.555195508801959e-09, name='NODE_0000399')
#                                                         Clade(branch_length=6.555195508801959e-09, name='Brazil/2016/ZBRC14')
#                                                         Clade(branch_length=6.555195508801959e-09, name='ZBRC15')
#                             Clade(branch_length=9.28934340025337e-05, name='NODE_0000284')
#                                 Clade(branch_length=0.002328555598867488, name='SG_118')
#                                 Clade(branch_length=0.00018580016188485043, name='NODE_0000091')
#                                     Clade(branch_length=6.555195508801959e-09, name='NODE_0000401')
#                                         Clade(branch_length=0.0007435859154778903, name='Brazil/2015/ZBRC321')
#                                         Clade(branch_length=9.289264752692034e-05, name='NODE_0000092')
#                                             Clade(branch_length=0.0013023506478954771, name='NODE_0000093')
#                                                 Clade(branch_length=9.288131168757588e-05, name='EcEs089_16')
#                                                 Clade(branch_length=0.000278693803883357, name='EcEs062_16')
#                                             Clade(branch_length=6.555195508801959e-09, name='NODE_0000402')
#                                                 Clade(branch_length=0.00037167867748767215, name='Brazil/2016/ZBRX16')
#                                                 Clade(branch_length=0.0008366717036687858, name='NODE_0000095')
#                                                     Clade(branch_length=6.555195508801959e-09, name='Paraiba_01')
#                                                     Clade(branch_length=0.00046465595677316245, name='Brazil_2015_MG')
#                                     Clade(branch_length=9.289351754964434e-05, name='NODE_0000088')
#                                         Clade(branch_length=9.289430394108632e-05, name='NODE_0000089')
#                                             Clade(branch_length=0.0017676137792410626, name='Rio_S1')
#                                             Clade(branch_length=0.0015815127130123386, name='Natal_RGN')
#                                         Clade(branch_length=0.0001858017638851888, name='NODE_0000087')
#                                             Clade(branch_length=0.0013952373418891291, name='BeH823339')
#                                             Clade(branch_length=9.28935175730861e-05, name='NODE_0000086')
#                                                 Clade(branch_length=0.00027872643782402007, name='Brazil/2015/ZBRA105')
#                                                 Clade(branch_length=9.289351754964434e-05, name='NODE_0000085')
#                                                     Clade(branch_length=6.555195508801959e-09, name='NODE_0000403')
#                                                         Clade(branch_length=0.0002787283763536772, name='DOM/2016/MA_WGS16_020')
#                                                         Clade(branch_length=0.001674862414712867, name='Saint_Barthelemi_Rus_6BRN_2016')
#                                                     Clade(branch_length=0.0003716735060532192, name='NODE_0000001')
#                                                         Clade(branch_length=6.555195508801959e-09, name='NODE_0000404')
#                                                             Clade(branch_length=9.289691426810163e-05, name='Brazil/2016/ZBRY11')
#                                                             Clade(branch_length=0.00046464223209596953, name='Brazil/2016/ZBRY14')
#                                                         Clade(branch_length=0.0006506501384853048, name='NODE_0000003')
#                                                             Clade(branch_length=6.555195508801959e-09, name='NODE_0000405')
#                                                                 Clade(branch_length=0.000743719545864989, name='DOM/2016/BB_0216')
#                                                                 Clade(branch_length=0.0004647039697905815, name='DOM/2016/BB_0180')
#                                                             Clade(branch_length=9.290060987638847e-05, name='NODE_0000005')
#                                                                 Clade(branch_length=0.0006506243222587425, name='NODE_0000012')
#                                                                     Clade(branch_length=0.00018581612782749175, name='mosquito/Haiti/1682/2016')
#                                                                     Clade(branch_length=0.0001858230128794977, name='NODE_0000013')
#                                                                         Clade(branch_length=9.289533616871001e-05, name='NODE_0000406')
#                                                                             Clade(branch_length=0.0006506006988065815, name='PHE_Guadeloupe')
#                                                                             Clade(branch_length=6.555195508801959e-09, name='Haiti/0054/2014')
#                                                                         Clade(branch_length=6.555195508801959e-09, name='NODE_0000015')
#                                                                             Clade(branch_length=6.555195508801959e-09, name='Haiti/0033/2014')
#                                                                             Clade(branch_length=6.555195508801959e-09, name='Haiti/0036/2014')
#                                                                             Clade(branch_length=6.555195508801959e-09, name='Haiti/0029/2014')
#                                                                             Clade(branch_length=9.289454960175608e-05, name='NODE_0000016')
#                                                                                 Clade(branch_length=6.555195508801959e-09, name='Haiti/0074/2014')
#                                                                                 Clade(branch_length=6.555195508801959e-09, name='Haiti/0097/2014')
#                                                                 Clade(branch_length=6.555195508801959e-09, name='NODE_0000407')
#                                                                     Clade(branch_length=9.290060986175087e-05, name='NODE_0000036')
#                                                                         Clade(branch_length=0.0022339476682560495, name='Cuba_2017')
#                                                                         Clade(branch_length=0.0010229081786453393, name='DOM/2016/BB_0433')
#                                                                     Clade(branch_length=6.555195508801959e-09, name='NODE_0000408')
#                                                                         Clade(branch_length=0.0007436256208648456, name='NODE_0000024')
#                                                                             Clade(branch_length=0.0004646444612755353, name='NODE_0000025')
#                                                                                 Clade(branch_length=0.0015815833608714353, name='USVI/28/2016')
#                                                                                 Clade(branch_length=0.00018580899714685812, name='USVI/42/2016')
#                                                                             Clade(branch_length=0.0002787423111541027, name='NODE_0000026')
#                                                                                 Clade(branch_length=0.0016754171493043382, name='USVI/20/2016')
#                                                                                 Clade(branch_length=9.28979994804886e-05, name='NODE_0000027')
#                                                                                     Clade(branch_length=0.00018581215092849847, name='USVI/19/2016')
#                                                                                     Clade(branch_length=0.0003716879768438921, name='USVI/41/2016')
#                                                                         Clade(branch_length=6.555195508801959e-09, name='NODE_0000409')
#                                                                             Clade(branch_length=0.00027875206786556273, name='NODE_0000032')
#                                                                                 Clade(branch_length=0.0008366685300232523, name='DOM/2016/MA_WGS16_013')
#                                                                                 Clade(branch_length=0.0009297168748036979, name='DOM/2016/BB_0091')
#                                                                             Clade(branch_length=6.555195508801959e-09, name='NODE_0000410')
#                                                                                 Clade(branch_length=0.0013951335225300247, name='NODE_0000044')
#                                                                                     Clade(branch_length=9.29025027529137e-05, name='Dominican_Republic/2016/ZB')
#                                                                                     Clade(branch_length=6.555195508801959e-09, name='NODE_0000411')
#                                                                                         Clade(branch_length=6.555195508801959e-09, name='Dominican_Rep_Rus_8ZBR_2016')
#                                                                                         Clade(branch_length=6.555195508801959e-09, name='Dominican_Rep_Rus_7EGR_2016')
#                                                                                 Clade(branch_length=6.555195508801959e-09, name='NODE_0000412')
#                                                                                     Clade(branch_length=0.0008366988892135846, name='DOM/2016/BB_0071')
#                                                                                     Clade(branch_length=6.555195508801959e-09, name='NODE_0000413')
#                                                                                         Clade(branch_length=9.290060986175087e-05, name='NODE_0000010')
#                                                                                             Clade(branch_length=0.0010229348502742075, name='DOM/2016/BB_0436')
#                                                                                             Clade(branch_length=6.555195508801959e-09, name='NODE_0000414')
#                                                                                                 Clade(branch_length=0.0006506370787421334, name='DOM/2016/MA_WGS16_014')
#                                                                                                 Clade(branch_length=0.0007436709123477703, name='DOM/2016/BB_0115')
#                                                                                         Clade(branch_length=6.555195508801959e-09, name='NODE_0000415')
#                                                                                             Clade(branch_length=0.0001858145329585166, name='NODE_0000022')
#                                                                                                 Clade(branch_length=0.0002787628666397193, name='Dominican_Republic/2016/PD1')
#                                                                                                 Clade(branch_length=0.0008368346962992993, name='USA/2016/FL039')
#                                                                                             Clade(branch_length=6.555195508801959e-09, name='NODE_0000416')
#                                                                                                 Clade(branch_length=0.0003716949544852444, name='NODE_0000043')
#                                                                                                     Clade(branch_length=0.0003717009860792816, name='DOM/2016/BB_0269')
#                                                                                                     Clade(branch_length=0.00027878539123800134, name='DOM/2016/BB_0183')
#                                                                                                 Clade(branch_length=6.555195508801959e-09, name='NODE_0000417')
#                                                                                                     Clade(branch_length=0.0006506220667939814, name='Yokohama/1/2016')
#                                                                                                     Clade(branch_length=6.555195508801959e-09, name='NODE_0000418')
#                                                                                                         Clade(branch_length=0.0006506209691887308, name='NODE_0000034')
#                                                                                                             Clade(branch_length=6.555195508801959e-09, name='Dominican_Rep_Rus_5RMN_2016')
#                                                                                                             Clade(branch_length=9.289973969415447e-05, name='DOM/2016/MA_WGS16_031')
#                                                                                                         Clade(branch_length=6.555195508801959e-09, name='NODE_0000419')
#                                                                                                             Clade(branch_length=0.000557641606891065, name='DOM/2016/BB_0076')
#                                                                                                             Clade(branch_length=6.555195508801959e-09, name='NODE_0000420')
#                                                                                                                 Clade(branch_length=0.0002787470817344688, name='NODE_0000038')
#                                                                                                                     Clade(branch_length=0.0002787418486152474, name='Dominican_Rep_Rus_3ALT_2016')
#                                                                                                                     Clade(branch_length=9.289973969415447e-05, name='NODE_0000039')
#                                                                                                                         Clade(branch_length=0.0007436335514778864, name='USVI/22/2016')
#                                                                                                                         Clade(branch_length=0.00018583433591516218, name='NODE_0000040')
#                                                                                                                             Clade(branch_length=0.0006506668538623552, name='DOM/2016/MA_WGS16_040')
#                                                                                                                             Clade(branch_length=6.555195508801959e-09, name='DOM/2016/MA_WGS16_036')
#                                                                                                                 Clade(branch_length=6.555195508801959e-09, name='NODE_0000421')
#                                                                                                                     Clade(branch_length=6.555195508801959e-09, name='NODE_0000422')
#                                                                                                                         Clade(branch_length=0.0002787494512237411, name='NODE_0000029')
#                                                                                                                             Clade(branch_length=0.0003717128091652233, name='DOM/2016/MA_WGS16_011')
#                                                                                                                             Clade(branch_length=0.0002787492038622639, name='DOM/2016/MA_WGS16_024')
#                                                                                                                         Clade(branch_length=6.555195508801959e-09, name='NODE_0000423')
#                                                                                                                             Clade(branch_length=0.0005576965631425841, name='DOM/2016/BB_0428')
#                                                                                                                             Clade(branch_length=6.555195508801959e-09, name='NODE_0000424')
#                                                                                                                                 Clade(branch_length=0.00027875978715121525, name='JAM/2016/MA_WGS16_038')
#                                                                                                                                 Clade(branch_length=0.000185821252046373, name='Haiti/2016/PD')
#                                                                                                                     Clade(branch_length=9.289973969164433e-05, name='NODE_0000046')
#                                                                                                                         Clade(branch_length=0.0009296921970278669, name='NODE_0000052')
#                                                                                                                             Clade(branch_length=0.00037169557376185314, name='NODE_0000053')
#                                                                                                                                 Clade(branch_length=6.555195508801959e-09, name='USA/2016/FLUR058')
#                                                                                                                                 Clade(branch_length=9.290171609022124e-05, name='USA/2016/FLSR036')
#                                                                                                                             Clade(branch_length=9.290124399343336e-05, name='NODE_0000054')
#                                                                                                                                 Clade(branch_length=9.290124398407713e-05, name='NODE_0000055')
#                                                                                                                                     Clade(branch_length=0.00018581580318295394, name='Aedes_aegypti/USA/2016/FL05')
#                                                                                                                                     Clade(branch_length=0.00018581533036625582, name='USA/2016/FLUR014')
#                                                                                                                                 Clade(branch_length=9.290124398407713e-05, name='NODE_0000056')
#                                                                                                                                     Clade(branch_length=0.00027875111079893496, name='USA/2016/FL032')
#                                                                                                                                     Clade(branch_length=9.290052632755265e-05, name='NODE_0000060')
#                                                                                                                                         Clade(branch_length=0.00037169146563774836, name='Aedes_aegypti/USA/2016/FL04')
#                                                                                                                                         Clade(branch_length=6.555195508801959e-09, name='USA/2016/MA_WGS16_034')
#                                                                                                                                     Clade(branch_length=6.555195508801959e-09, name='NODE_0000425')
#                                                                                                                                         Clade(branch_length=9.290052632755265e-05, name='Aedes_aegypti/USA/2016/FL03')
#                                                                                                                                         Clade(branch_length=6.555195508801959e-09, name='NODE_0000426')
#                                                                                                                                             Clade(branch_length=6.555195508801959e-09, name='USA/2016/FL035')
#                                                                                                                                             Clade(branch_length=6.555195508801959e-09, name='USA/2016/FLUR026')
#                                                                                                                         Clade(branch_length=6.555195508801959e-09, name='NODE_0000427')
#                                                                                                                             Clade(branch_length=9.28997396941549e-05, name='NODE_0000048')
#                                                                                                                                 Clade(branch_length=0.0004646775458935805, name='NODE_0000049')
#                                                                                                                                     Clade(branch_length=0.0003717105936951511, name='DOM/2016/MA_WGS16_007')
#                                                                                                                                     Clade(branch_length=9.28958916587971e-05, name='DOM/2016/BB_0208')
#                                                                                                                                 Clade(branch_length=0.0007436633830790055, name='NODE_0000050')
#                                                                                                                                     Clade(branch_length=0.000743587176150559, name='JAM/2016/MA_WGS16_041')
#                                                                                                                                     Clade(branch_length=9.289478561226583e-05, name='JAM/2016/MA_WGS16_039')
#                                                                                                                             Clade(branch_length=6.555195508801959e-09, name='NODE_0000428')
#                                                                                                                                 Clade(branch_length=0.0005576308948291781, name='JAM/2016/MA_WGS16_025')
#                                                                                                                                 Clade(branch_length=9.290757739000488e-05, name='NODE_0000061')
#                                                                                                                                     Clade(branch_length=0.0011158947535563693, name='USVI/7/2016')
#                                                                                                                                     Clade(branch_length=6.555195508801959e-09, name='NODE_0000429')
#                                                                                                                                         Clade(branch_length=0.00046468790706976314, name='Dominican_Rep_Rus_4MRG_2016')
#                                                                                                                                         Clade(branch_length=0.0001858262171713929, name='NODE_0000063')
#                                                                                                                                             Clade(branch_length=0.00027876483246275317, name='DOM/2016/BB_0059')
#                                                                                                                                             Clade(branch_length=0.00027876554235131256, name='NODE_0000064')
#                                                                                                                                                 Clade(branch_length=0.00046468811005104336, name='USA/2016/FL029')
#                                                                                                                                                 Clade(branch_length=9.29052450109498e-05, name='NODE_0000065')
#                                                                                                                                                     Clade(branch_length=6.555195508801959e-09, name='USA/2016/FL028')
#                                                                                                                                                     Clade(branch_length=9.290532858844194e-05, name='NODE_0000066')
#                                                                                                                                                         Clade(branch_length=0.0005576702082527593, name='USA/2016/FL022')
#                                                                                                                                                         Clade(branch_length=0.0002787643451584998, name='USA/2016/FLUR006')
#                                                                                                                                                         Clade(branch_length=9.290548112033791e-05, name='NODE_0000081')
#                                                                                                                                                             Clade(branch_length=9.290654534026364e-05, name='USA/2016/FLUR005')
#                                                                                                                                                             Clade(branch_length=0.00046476966467746354, name='HTI/2016/MA_WGS16_022')
#                                                                                                                                                             Clade(branch_length=0.00027876434515414477, name='USA/2016/FL030')
#                                                                                                                                                         Clade(branch_length=6.555195508801959e-09, name='NODE_0000491')
#                                                                                                                                                             Clade(branch_length=0.0002787718249441101, name='USA/2016/FL038')
#                                                                                                                                                             Clade(branch_length=6.555195508801959e-09, name='NODE_0000492')
#                                                                                                                                                                 Clade(branch_length=9.290532859028856e-05, name='NODE_0000069')
#                                                                                                                                                                     Clade(branch_length=0.00018582525367136487, name='USA/2016/FL021')
#                                                                                                                                                                     Clade(branch_length=0.0002787614810080101, name='USA/2016/FLUR002')
#                                                                                                                                                                     Clade(branch_length=6.555195508801959e-09, name='NODE_0000430')
#                                                                                                                                                                         Clade(branch_length=0.00027876920780362836, name='Aedes_aegypti/USA/2016/FL08')
#                                                                                                                                                                         Clade(branch_length=6.555195508801959e-09, name='NODE_0000431')
#                                                                                                                                                                             Clade(branch_length=6.555195508801959e-09, name='USA/2016/FLUR007')
#                                                                                                                                                                             Clade(branch_length=9.290524502646343e-05, name='USA/2016/FLUR008')
#                                                                                                                                                                 Clade(branch_length=6.555195508801959e-09, name='NODE_0000432')
#                                                                                                                                                                     Clade(branch_length=0.00018584112239434375, name='USA/2016/FLUR001')
#                                                                                                                                                                     Clade(branch_length=6.555195508801959e-09, name='NODE_0000433')
#                                                                                                                                                                         Clade(branch_length=0.00018582525359216433, name='USA/2016/FLUR009')
#                                                                                                                                                                         Clade(branch_length=6.555195508801959e-09, name='NODE_0000434')
#                                                                                                                                                                             Clade(branch_length=0.00027876671482662645, name='NODE_0000084')
#                                                                                                                                                                                 Clade(branch_length=6.555195508801959e-09, name='USA/2016/FLUR057')
#                                                                                                                                                                                 Clade(branch_length=6.555195508801959e-09, name='USA/2016/FLWB042')
#                                                                                                                                                                             Clade(branch_length=6.555195508801959e-09, name='NODE_0000435')
#                                                                                                                                                                                 Clade(branch_length=6.555195508801959e-09, name='NODE_0000436')
#                                                                                                                                                                                     Clade(branch_length=6.555195508801959e-09, name='USA/2016/FLUR013')
#                                                                                                                                                                                     Clade(branch_length=6.555195508801959e-09, name='USA/2016/FL010')
#                                                                                                                                                                                 Clade(branch_length=0.0001858254197247512, name='NODE_0000076')
#                                                                                                                                                                                     Clade(branch_length=6.555195508801959e-09, name='USA/2016/FLUR015')
#                                                                                                                                                                                     Clade(branch_length=9.290532859028856e-05, name='USA/2016/FLUR063')
#                                                                                                                                                                                     Clade(branch_length=6.555195508801959e-09, name='Aedes_aegypti/USA/2016/FL06')
#                                 Clade(branch_length=6.555195508801959e-09, name='NODE_0000493')
#                                     Clade(branch_length=9.289264752692034e-05, name='NODE_0000299')
#                                         Clade(branch_length=9.28925639789367e-05, name='NODE_0000300')
#                                             Clade(branch_length=0.001115754610794147, name='Brazil/2015/ZBRD116')
#                                             Clade(branch_length=0.0011157240794136929, name='BeH828305')
#                                         Clade(branch_length=0.0009297932526801116, name='NODE_0000301')
#                                             Clade(branch_length=0.0008367105148412721, name='Bahia01')
#                                             Clade(branch_length=0.00018578676359131286, name='NODE_0000302')
#                                                 Clade(branch_length=0.0003716345905658133, name='Bahia02')
#                                                 Clade(branch_length=0.00046459162910873677, name='NODE_0000303')
#                                                     Clade(branch_length=9.288895261265256e-05, name='NODE_0000304')
#                                                         Clade(branch_length=6.555195508801959e-09, name='Bahia07')
#                                                         Clade(branch_length=9.288967003945672e-05, name='NODE_0000305')
#                                                             Clade(branch_length=6.555195508801959e-09, name='Bahia09')
#                                                             Clade(branch_length=0.00027872853681184346, name='HS_2015_BA_01')
#                                                     Clade(branch_length=9.289828556634152e-05, name='NODE_0000306')
#                                                         Clade(branch_length=0.00046462201568637715, name='Bahia03')
#                                                         Clade(branch_length=6.555195508801959e-09, name='NODE_0000400')
#                                                             Clade(branch_length=0.00018580207073145248, name='Bahia08')
#                                                             Clade(branch_length=0.0005577028448797159, name='Bahia15')
#                                     Clade(branch_length=6.555195508801959e-09, name='NODE_0000437')
#                                         Clade(branch_length=6.555195508801959e-09, name='NODE_0000438')
#                                             Clade(branch_length=0.00037165824952989975, name='NODE_0000286')
#                                                 Clade(branch_length=0.0023270522827917774, name='USVI/36/2016')
#                                                 Clade(branch_length=0.00018579272573974927, name='NODE_0000287')
#                                                     Clade(branch_length=0.0006505284451290829, name='Brazil/2016/ZBRX1')
#                                                     Clade(branch_length=0.0002787148084794108, name='NODE_0000288')
#                                                         Clade(branch_length=6.555195508801959e-09, name='NODE_0000439')
#                                                             Clade(branch_length=6.555195508801959e-09, name='Brazil/2016/ZBRX137')
#                                                             Clade(branch_length=0.00027871480844670303, name='Brazil/2016/ZBRX6')
#                                                         Clade(branch_length=0.0004645906805218745, name='NODE_0000290')
#                                                             Clade(branch_length=6.555195508801959e-09, name='Brazil/2016/ZBRX103')
#                                                             Clade(branch_length=0.0005575373302337009, name='Brazil/2016/ZBRX13')
# ...
#                                                                     Clade(branch_length=0.000464615983892221, name='mex07/Mexico/2016')
#                                                                     Clade(branch_length=0.0005575603496773942, name='NODE_0000215')
#                                                                         Clade(branch_length=6.555195508801959e-09, name='MEX_ENCB165')
#                                                                         Clade(branch_length=6.555195508801959e-09, name='ENCB165P4')
#                                                                     Clade(branch_length=0.0013018939587083177, name='NODE_0000217')
#                                                                         Clade(branch_length=6.555195508801959e-09, name='USA/UT_1/2016')
#                                                                         Clade(branch_length=6.555195508801959e-09, name='R116265')
#                                                                 Clade(branch_length=6.555195508801959e-09, name='NODE_0000468')
#                                                                     Clade(branch_length=0.0006505066995960256, name='NODE_0000207')
#                                                                         Clade(branch_length=0.00018579082497735457, name='Aedes_aegypti/MEX/MEX_I_44/2016')
#                                                                         Clade(branch_length=6.555195508801959e-09, name='Aedes_sp/MEX_I_44/2016')
#                                                                     Clade(branch_length=6.555195508801959e-09, name='NODE_0000469')
#                                                                         Clade(branch_length=0.0013021294913811389, name='Mexico_Rus_12TVR_2017')
#                                                                         Clade(branch_length=9.28820195374388e-05, name='NODE_0000211')
#                                                                             Clade(branch_length=0.00037162045088174776, name='MEX_CIENI551')
#                                                                             Clade(branch_length=9.288193607649969e-05, name='NODE_0000212')
#                                                                                 Clade(branch_length=0.0005575281866037848, name='Aedessp/MEX/MEX_2_81/2016')
#                                                                                 Clade(branch_length=0.0002786978387967318, name='NODE_0000213')
#                                                                                     Clade(branch_length=9.28847909469838e-05, name='MEX_I_7')
#                                                                                     Clade(branch_length=0.00018578080176539363, name='Aedessp/MEX/MEX_I_7/2016')
#                                                             Clade(branch_length=6.555195508801959e-09, name='NODE_0000494')
#                                                                 Clade(branch_length=0.00018577002349313846, name='NODE_0000168')
#                                                                     Clade(branch_length=0.0006504655935802833, name='NODE_0000169')
#                                                                         Clade(branch_length=0.0011158281135608067, name='NIC/8610_13A1/2016')
#                                                                         Clade(branch_length=0.0014879846681303084, name='NIC/5256_13A1/2016')
#                                                                     Clade(branch_length=0.00037159698624022455, name='NODE_0000170')
#                                                                         Clade(branch_length=0.00018576526956915178, name='NODE_0000171')
#                                                                             Clade(branch_length=9.287529762957254e-05, name='HN16')
#                                                                             Clade(branch_length=9.287529762957254e-05, name='NODE_0000172')
#                                                                                 Clade(branch_length=0.0005574846289007167, name='HND/2016/HU_ME58')
#                                                                                 Clade(branch_length=0.0005574701382487337, name='HND/2016/HU_ME156')
#                                                                         Clade(branch_length=9.287616727249098e-05, name='NODE_0000173')
#                                                                             Clade(branch_length=0.0005574896472227645, name='HND/2016/HU_ME42')
#                                                                             Clade(branch_length=9.287695348034414e-05, name='NODE_0000174')
#                                                                                 Clade(branch_length=0.0005576141916263867, name='HND/2016/HU_ME38')
#                                                                                 Clade(branch_length=0.00018576653912106243, name='NODE_0000178')
#                                                                                     Clade(branch_length=0.0006504989458862918, name='NIC/6547_13A1/2016')
#                                                                                     Clade(branch_length=0.0007434596700908306, name='NODE_0000179')
#                                                                                         Clade(branch_length=0.00018574994333320823, name='NIC/4886_12A1/2016')
#                                                                                         Clade(branch_length=9.286844513247891e-05, name='NIC/7252_12A1/2016')
#                                                                                 Clade(branch_length=6.555195508801959e-09, name='NODE_0000466')
#                                                                                     Clade(branch_length=0.0005575519763904046, name='HND/2016/HU_ME147')
#                                                                                     Clade(branch_length=6.555195508801959e-09, name='NODE_0000467')
#                                                                                         Clade(branch_length=9.2881022638127e-05, name='USA/2016/FL019')
#                                                                                         Clade(branch_length=0.0003716488229740457, name='HND/2016/HU_ME33')
#                                                                 Clade(branch_length=6.555195508801959e-09, name='NODE_0000470')
#                                                                     Clade(branch_length=9.287932680303182e-05, name='NODE_0000164')
#                                                                         Clade(branch_length=0.0008365651512054471, name='mex48/Mexico/2016')
#                                                                         Clade(branch_length=0.0007434889339400022, name='NODE_0000165')
#                                                                             Clade(branch_length=9.287081790406446e-05, name='V103344')
#                                                                             Clade(branch_length=6.555195508801959e-09, name='V8375')
#                                                                     Clade(branch_length=6.555195508801959e-09, name='NODE_0000471')
#                                                                         Clade(branch_length=6.555195508801959e-09, name='NODE_0000472')
#                                                                             Clade(branch_length=0.0013017376025927338, name='NODE_0000167')
#                                                                                 Clade(branch_length=6.555195508801959e-09, name='USA/2016/FLWB044')
#                                                                                 Clade(branch_length=6.555195508801959e-09, name='USA/2016/FLSR043')
#                                                                             Clade(branch_length=6.555195508801959e-09, name='NODE_0000473')
#                                                                                 Clade(branch_length=0.000743468348689181, name='Mex03/Mexico/2016')
#                                                                                 Clade(branch_length=6.555195508801959e-09, name='NODE_0000474')
#                                                                                     Clade(branch_length=0.0010225046772579624, name='Henan/001/2016')
#                                                                                     Clade(branch_length=6.555195508801959e-09, name='NODE_0000475')
#                                                                                         Clade(branch_length=0.0009295700887208889, name='Cuba/2017/Hu0046Sa')
#                                                                                         Clade(branch_length=9.287941017048669e-05, name='NODE_0000197')
#                                                                                             Clade(branch_length=6.555195508801959e-09, name='NODE_0000476')
#                                                                                                 Clade(branch_length=0.00037161093492114883, name='UNK/2016/MA_WGS16_029')
#                                                                                                 Clade(branch_length=0.00027869094842928504, name='NODE_0000199')
#                                                                                                     Clade(branch_length=0.0005575910351767431, name='HND/2016/HU_ME152')
#                                                                                                     Clade(branch_length=6.555195508801959e-09, name='HND/2016/HU_ME59')
#                                                                                             Clade(branch_length=9.288985285181963e-05, name='NODE_0000200')
#                                                                                                 Clade(branch_length=0.00018578596644321837, name='NODE_0000201')
#                                                                                                     Clade(branch_length=0.00046461492926553336, name='NIC/5005_13A1/2016')
#                                                                                                     Clade(branch_length=0.0005576098590376532, name='FHT1175/HON/2016')
#                                                                                                 Clade(branch_length=9.288650036852605e-05, name='NODE_0000202')
#                                                                                                     Clade(branch_length=0.0003716418931348649, name='HND/2016/HU_ME136')
#                                                                                                     Clade(branch_length=0.0006506183442787387, name='NIC/5847_12B1/2016')
#                                                                                                     Clade(branch_length=9.28873702265888e-05, name='NODE_0000204')
#                                                                                                         Clade(branch_length=0.0007435251975116612, name='HND/2016/HU_ME167')
#                                                                                                         Clade(branch_length=0.0008365383727206624, name='HND/2016/HU_ME50')
#                                                                                                         Clade(branch_length=0.0007435602947379739, name='HND/2016/HU_ME178')
#                                                                         Clade(branch_length=9.287932680303182e-05, name='NODE_0000181')
#                                                                             Clade(branch_length=0.00279797298937331, name='mex39/Mexico/2016')
#                                                                             Clade(branch_length=6.555195508801959e-09, name='NODE_0000477')
#                                                                                 Clade(branch_length=9.288004401550396e-05, name='NODE_0000183')
#                                                                                     Clade(branch_length=0.000557518203255431, name='HND/2016/HU_ME180')
#                                                                                     Clade(branch_length=0.0011156128748953786, name='FB_GWUH_2016')
#                                                                                 Clade(branch_length=6.555195508801959e-09, name='NODE_0000478')
#                                                                                     Clade(branch_length=0.0004645748844078774, name='NODE_0000186')
#                                                                                         Clade(branch_length=0.0013018480777830296, name='NIC/6406_13A1/2016')
#                                                                                         Clade(branch_length=6.555195508801959e-09, name='NODE_0000479')
#                                                                                             Clade(branch_length=6.555195508801959e-09, name='Nica2_16')
#                                                                                             Clade(branch_length=6.555195508801959e-09, name='Nica1_16')
#                                                                                     Clade(branch_length=6.555195508801959e-09, name='NODE_0000480')
#                                                                                         Clade(branch_length=0.0006504825372328068, name='HND/2016/HU_ME137')
#                                                                                         Clade(branch_length=9.287917428863618e-05, name='NODE_0000188')
#                                                                                             Clade(branch_length=0.0011156118688886805, name='NIC/1659_13A1/2016')
#                                                                                             Clade(branch_length=0.0003716026876440597, name='HND/2016/HU_SZ76')
#                                                                                             Clade(branch_length=9.287830450984899e-05, name='NODE_0000190')
#                                                                                                 Clade(branch_length=0.0014879221580915373, name='NIC/7253_13A1/2016')
#                                                                                                 Clade(branch_length=0.0013018994399406209, name='NIC/1304_13A1/2016')
#                                                                                                 Clade(branch_length=0.0009294749190695015, name='NIC/5338_13A1/2016')
#                                                                                                 Clade(branch_length=6.555195508801959e-09, name='NODE_0000481')
#                                                                                                     Clade(branch_length=0.0007434480356881693, name='HND/2016/HU_ME171')
#                                                                                                     Clade(branch_length=6.555195508801959e-09, name='NODE_0000482')
#                                                                                                         Clade(branch_length=0.000371643248902188, name='HND/2016/HU_ME172')
#                                                                                                         Clade(branch_length=0.0002786804863937741, name='NODE_0000192')
#                                                                                                             Clade(branch_length=6.555195508801959e-09, name='HND/2016/HU_ME131')
#                                                                                                             Clade(branch_length=0.0003716033067546797, name='FHT1166/HON/2016')

# %%
#dir(tree)
#tree.get_terminals()

# %%
#tree.count_terminals()# Counts the number of terminal (leaf) nodes within this tree.

# %% [markdown]
# The functions `get_x_coordinates()`, `get_y_coordinates()` are mainly the functions with the samename
# from Biopython: [https://github.com/biopython/biopython/blob/master/Bio/Phylo/_utils.py](https://github.com/biopython/biopython/blob/master/Bio/Phylo/_utils.py).

# %%
def get_x_coordinates(tree):
    """Associates to  each clade an x-coord.
       returns dict {clade: x-coord}
    """
    xcoords = tree.depths()
    #tree.depth() maps tree clades to depths (by branch length).
    #returns a dict {clade: depth} where clade runs over all Clade instances of the tree, and depth is the distance from root
    #to clade
    
    #  If there are no branch lengths, assign unit branch lengths
    if not max(xcoords.values()):
        xcoords = tree.depths(unit_branch_lengths=True)
    return xcoords
   
def get_y_coordinates(tree, dist=1.3):
    """
       returns  dict {clade: y-coord}
       The y-coordinates are  (float) multiple of integers (i*dist below)
       dist depends on the number of tree leafs
        """
    maxheight = tree.count_terminals()#Counts the number of tree leafs.
    # Rows are defined by the tips/leafs
    ycoords = dict((leaf, maxheight - i*dist) for i, leaf in enumerate(reversed(tree.get_terminals())))
    def calc_row(clade):
            for subclade in clade:
                if subclade not in ycoords:
                    calc_row(subclade)
            ycoords[clade] = (ycoords[clade.clades[0]] +
                              ycoords[clade.clades[-1]]) / 2

    if tree.root.clades:
        calc_row(tree.root)
    return ycoords

# %%
x_coords = get_x_coordinates(tree)
y_coords = get_y_coordinates(tree)
                             
print(x_coords)
print(y_coords)
# Out:
# {Clade(branch_length=0.0, name='NODE_0000385'): 0, Clade(branch_length=6.555195508771621e-09, name='NODE_0000349'): 6.555195508771621e-09, Clade(branch_length=0.005791682797542086, name='NIID123/2016'): 0.005791689352737594, Clade(branch_length=0.004384661968494351, name='NODE_0000355'): 0.00438466852368986, Clade(branch_length=0.0005576851603132952, name='ZKA_16_097'): 0.004942353684003155, Clade(branch_length=0.0006507515846834455, name='SG_108'): 0.005035420108373306, Clade(branch_length=9.291026105521637e-05, name='NODE_0000363'): 0.0044775787847450765, Clade(branch_length=6.555195508801959e-09, name='SG_037'): 0.004477585339940585, Clade(branch_length=9.291097893227018e-05, name='NODE_0000365'): 0.004570489763677347, Clade(branch_length=0.0003717753998666298, name='SG_046'): 0.0049422651635439765, Clade(branch_length=0.00018585767239837157, name='SG_027'): 0.004756347436075718, Clade(branch_length=6.555195508801959e-09, name='NODE_0000483'): 0.004384675078885369, Clade(branch_length=9.290947432497292e-05, name='NODE_0000380'): 0.004477584553210342, Clade(branch_length=0.00027877872499755627, name='SG_109'): 0.004756363278207898, Clade(branch_length=9.290947433932863e-05, name='SG_111'): 0.0045704940275496705, Clade(branch_length=6.555195508801959e-09, name='NODE_0000484'): 0.004384681634080878, Clade(branch_length=0.00018583530356231556, name='SG_063'): 0.004570516937643193, Clade(branch_length=6.555195508801959e-09, name='NODE_0000485'): 0.0043846881892763865, Clade(branch_length=9.290947432497292e-05, name='NODE_0000373'): 0.0044775976636013595, Clade(branch_length=6.555195508801959e-09, name='SG_105'): 0.004477604218796868, Clade(branch_length=9.290947433932863e-05, name='NODE_0000374'): 0.004570507137940688, Clade(branch_length=9.291132535257929e-05, name='SG_020'): 0.004663418463293267, Clade(branch_length=6.555195508801959e-09, name='SG_016'): 0.004570513693136197, Clade(branch_length=6.555195508801959e-09, name='NODE_0000486'): 0.004384694744471895, Clade(branch_length=9.291034462908989e-05, name='NODE_0000358'): 0.004477605089100985, Clade(branch_length=0.00018583704705949639, name='SG_013'): 0.004663442136160482, Clade(branch_length=6.555195508801959e-09, name='SG_061'): 0.004477611644296494, Clade(branch_length=6.555195508801959e-09, name='NODE_0000487'): 0.004384701299667404, Clade(branch_length=9.292894037943745e-05, name='NODE_0000359'): 0.004477630240046842, Clade(branch_length=9.290533770798474e-05, name='SG_008'): 0.004570535577754826, Clade(branch_length=6.555195508801959e-09, name='NODE_0000488'): 0.00447763679524235, Clade(branch_length=6.555195508801959e-09, name='SG_005'): 0.004477643350437859, Clade(branch_length=6.555195508801959e-09, name='NODE_0000489'): 0.004477643350437859, Clade(branch_length=6.555195508801959e-09, name='SG_097'): 0.004477649905633368, Clade(branch_length=6.555195508801959e-09, name='SG_014'): 0.004477649905633368, Clade(branch_length=6.555195508801959e-09, name='NODE_0000490'): 0.004384707854862913, Clade(branch_length=9.290962685398405e-05, name='SG_009'): 0.004477617481716897, Clade(branch_length=6.555195508801959e-09, name='NODE_0000386'): 0.004384714410058422, Clade(branch_length=9.291369890522799e-05, name='SG_025'): 0.00447762810896365, Clade(branch_length=6.555195508801959e-09, name='NODE_0000387'): 0.0043847209652539305, Clade(branch_length=6.555195508801959e-09, name='SG_102'): 0.004384727520449439, Clade(branch_length=6.555195508801959e-09, name='NODE_0000388'): 0.004384727520449439, Clade(branch_length=6.555195508801959e-09, name='SG_095'): 0.004384734075644948, Clade(branch_length=6.555195508801959e-09, name='NODE_0000389'): 0.004384734075644948, Clade(branch_length=6.555195508801959e-09, name='SG_033'): 0.004384740630840457, Clade(branch_length=6.555195508801959e-09, name='NODE_0000390'): 0.004384740630840457, Clade(branch_length=6.555195508801959e-09, name='SG_100'): 0.004384747186035966, Clade(branch_length=6.555195508801959e-09, name='NODE_0000391'): 0.00438474 ...
# {Clade(branch_length=0.0003716033067546797, name='FHT1166/HON/2016'): 377.0, Clade(branch_length=6.555195508801959e-09, name='HND/2016/HU_ME131'): 375.7, Clade(branch_length=0.000371643248902188, name='HND/2016/HU_ME172'): 374.4, Clade(branch_length=0.0007434480356881693, name='HND/2016/HU_ME171'): 373.1, Clade(branch_length=0.0009294749190695015, name='NIC/5338_13A1/2016'): 371.8, Clade(branch_length=0.0013018994399406209, name='NIC/1304_13A1/2016'): 370.5, Clade(branch_length=0.0014879221580915373, name='NIC/7253_13A1/2016'): 369.2, Clade(branch_length=0.0003716026876440597, name='HND/2016/HU_SZ76'): 367.9, Clade(branch_length=0.0011156118688886805, name='NIC/1659_13A1/2016'): 366.6, Clade(branch_length=0.0006504825372328068, name='HND/2016/HU_ME137'): 365.3, Clade(branch_length=6.555195508801959e-09, name='Nica1_16'): 364.0, Clade(branch_length=6.555195508801959e-09, name='Nica2_16'): 362.7, Clade(branch_length=0.0013018480777830296, name='NIC/6406_13A1/2016'): 361.4, Clade(branch_length=0.0011156128748953786, name='FB_GWUH_2016'): 360.1, Clade(branch_length=0.000557518203255431, name='HND/2016/HU_ME180'): 358.8, Clade(branch_length=0.00279797298937331, name='mex39/Mexico/2016'): 357.5, Clade(branch_length=0.0007435602947379739, name='HND/2016/HU_ME178'): 356.2, Clade(branch_length=0.0008365383727206624, name='HND/2016/HU_ME50'): 354.9, Clade(branch_length=0.0007435251975116612, name='HND/2016/HU_ME167'): 353.6, Clade(branch_length=0.0006506183442787387, name='NIC/5847_12B1/2016'): 352.3, Clade(branch_length=0.0003716418931348649, name='HND/2016/HU_ME136'): 351.0, Clade(branch_length=0.0005576098590376532, name='FHT1175/HON/2016'): 349.7, Clade(branch_length=0.00046461492926553336, name='NIC/5005_13A1/2016'): 348.4, Clade(branch_length=6.555195508801959e-09, name='HND/2016/HU_ME59'): 347.1, Clade(branch_length=0.0005575910351767431, name='HND/2016/HU_ME152'): 345.8, Clade(branch_length=0.00037161093492114883, name='UNK/2016/MA_WGS16_029'): 344.5, Clade(branch_length=0.0009295700887208889, name='Cuba/2017/Hu0046Sa'): 343.2, Clade(branch_length=0.0010225046772579624, name='Henan/001/2016'): 341.9, Clade(branch_length=0.000743468348689181, name='Mex03/Mexico/2016'): 340.6, Clade(branch_length=6.555195508801959e-09, name='USA/2016/FLSR043'): 339.3, Clade(branch_length=6.555195508801959e-09, name='USA/2016/FLWB044'): 338.0, Clade(branch_length=6.555195508801959e-09, name='V8375'): 336.7, Clade(branch_length=9.287081790406446e-05, name='V103344'): 335.4, Clade(branch_length=0.0008365651512054471, name='mex48/Mexico/2016'): 334.1, Clade(branch_length=0.0003716488229740457, name='HND/2016/HU_ME33'): 332.8, Clade(branch_length=9.2881022638127e-05, name='USA/2016/FL019'): 331.5, Clade(branch_length=0.0005575519763904046, name='HND/2016/HU_ME147'): 330.2, Clade(branch_length=9.286844513247891e-05, name='NIC/7252_12A1/2016'): 328.9, Clade(branch_length=0.00018574994333320823, name='NIC/4886_12A1/2016'): 327.6, Clade(branch_length=0.0006504989458862918, name='NIC/6547_13A1/2016'): 326.3, Clade(branch_length=0.0005576141916263867, name='HND/2016/HU_ME38'): 325.0, Clade(branch_length=0.0005574896472227645, name='HND/2016/HU_ME42'): 323.7, Clade(branch_length=0.0005574701382487337, name='HND/2016/HU_ME156'): 322.4, Clade(branch_length=0.0005574846289007167, name='HND/2016/HU_ME58'): 321.1, Clade(branch_length=9.287529762957254e-05, name='HN16'): 319.8, Clade(branch_length=0.0014879846681303084, name='NIC/5256_13A1/2016'): 318.5, Clade(branch_length=0.0011158281135608067, name='NIC/8610_13A1/2016'): 317.2, Clade(branch_length=0.00018578080176539363, name='Aedessp/MEX/MEX_I_7/2016'): 315.9, Clade(branch_length=9.28847909469838e-05, name='MEX_I_7'): 314.6, Clade(branch_length=0.0005575281866037848, name='Aedessp/MEX/MEX_2_81/2016'): 313.3, Clade(branch_length=0.00037162045088174776, name='MEX_CIENI551'): 312.0, Clade(branch_length=0.0013021294913811389, name='Mexico_Rus_12TVR_2017'): 310.7, Clade(branch_length=6.555195508801959e-09, name='Aed ...

# %%
def get_clade_lines(orientation='horizontal', y_curr=0, x_start=0, x_curr=0, y_bot=0, y_top=0,
                    line_color='rgb(25,25,25)', line_width=0.5):
    """define a shape of type 'line', for branch
    """
    branch_line=dict(type= 'line',
                     layer='below',
                     line=dict(color=line_color, 
                               width=line_width)
                     )
    if orientation=='horizontal':
        branch_line.update(x0=x_start,
                           y0=y_curr,
                           x1=x_curr,
                           y1=y_curr)
    elif orientation=='vertical':
        branch_line.update(x0=x_curr,
                           y0=y_bot,
                           x1=x_curr,
                           y1=y_top)
    else:
        raise ValueError("Line type can be 'horizontal' or 'vertical'")
       
    return branch_line    
        
    

def draw_clade(clade, x_start,  line_shapes,line_color='rgb(15,15,15)', line_width=1):
    """Recursively draw the tree branches, down from the given clade"""
    
    x_curr = x_coords[clade]
    y_curr = y_coords[clade]
   
    # Draw a horizontal line from start to here
    branch_line=get_clade_lines(orientation='horizontal', y_curr=y_curr, x_start=x_start, x_curr=x_curr,  
                                line_color=line_color, line_width=line_width)
   
    line_shapes.append(branch_line)
   
    if clade.clades:
        # Draw a vertical line connecting all children
        y_top = y_coords[clade.clades[0]]
        y_bot = y_coords[clade.clades[-1]]
       
        line_shapes.append(get_clade_lines(orientation='vertical', x_curr=x_curr, y_bot=y_bot, y_top=y_top,
                                           line_color=line_color, line_width=line_width))
       
        # Draw descendants
        for child in clade:
            draw_clade(child, x_curr, line_shapes)

# %%
line_shapes=[]
draw_clade(tree.root, 0, line_shapes, line_color='rgb(25,25,25)', line_width=1)

# %%
my_tree_clades=x_coords.keys()
X=[]
Y=[]
text=[]

for cl in my_tree_clades:
    X.append(x_coords[cl])
    Y.append(y_coords[cl])
    text.append(cl.name)

# %%
df=pd.read_csv('nextstrain_zika_metadata.csv')
df.columns
# Out:
# Index(['Strain', 'Accession', 'Date', 'Region', 'Country', 'Division',
#        'Authors', 'Journal', 'Title', 'Url', 'Num Date', 'Db', 'Raw Date'],
#       dtype='object')

# %%
len(df)
# Out:
# 377

# %%
set(list(df['Region']))
list(df['Accession'])
# Out:
# ['Lc219720',
#  'Kx813683',
#  'Ky241778',
#  'Ky241707',
#  'Ky241716',
#  'Ky241697',
#  'Ky241779',
#  'Ky241781',
#  'Ky241733',
#  'Ky241775',
#  'Ky241690',
#  'Ky241686',
#  'Ky241683',
#  'Ky241731',
#  'Ky241678',
#  'Ky241675',
#  'Ky241767',
#  'Ky241684',
#  'Ky241679',
#  'Ky241695',
#  'Ky241772',
#  'Ky241765',
#  'Ky241703',
#  'Ky241770',
#  'Ky241711',
#  'Ky241760',
#  'Ky241743',
#  'Ky241709',
#  'Kx447517',
#  'Kx447516',
#  'Kx447515',
#  'Kx447514',
#  'Kj776791',
#  'Kx447521',
#  'Kx447509',
#  'Lc191864',
#  'Kx806557',
#  'Ku761561',
#  'Ku761560',
#  'Kx117076',
#  'Kx185891',
#  'Ku963796',
#  'Kx013000',
#  'Ku997667',
#  'Ku866423',
#  'Kx266255',
#  'Mf036115',
#  'Ky967711',
#  'Ku955589',
#  'Kx253996',
#  'Kx447520',
#  'Kx447511',
#  'Kx447513',
#  'Kx447519',
#  'Kx369547',
#  'Kx447512',
#  'Kx447510',
#  'Kx447518',
#  'Kx051563',
#  'Ku509998',
#  'Ku321639',
#  'Kr872956',
#  'Mf352141',
#  'Kx197192',
#  'Ky558993',
#  'Zbrc13',
#  'Ky558990',
#  'Zbrc15',
#  'Ky241788',
#  'Ky559000',
#  'Kx879604',
#  'Kx879603',
#  'Ky559016',
#  'Kx280026',
#  'Kx811222',
#  'Ku926310',
#  'Ku527068',
#  'Ku729217',
#  'Ky558989',
#  'Ky785460',
#  'Mf098767',
#  'Ky559029',
#  'Ky817930',
#  'Ky014302',
#  'Ky014304',
#  'Mf384325',
#  'Kx673530',
#  'Ky415988',
#  'Ky415987',
#  'Ky415990',
#  'Ky415986',
#  'Ky415989',
#  'Ky415991',
#  'Mf438286',
#  'Ky785441',
#  'Vi28',
#  'Vi42',
#  'Vi20',
#  'Vi19',
#  'Vi41',
#  'Ky785473',
#  'Ky785475',
#  'Mf664436',
#  'Mf098769',
#  'Mf098768',
#  'Ky785449',
#  'Ky014314',
#  'Ky785470',
#  'Ky014321',
#  'Ku853012',
#  'Kx922707',
#  'Ky014318',
#  'Ky785420',
#  'Lc190723',
#  'Mf098766',
#  'Ky785434',
#  'Ky014305',
#  'Mf098764',
#  'Vi22',
#  'Ky785413',
#  'Ky785447',
#  'Ky785484',
#  'Ky785435',
#  'Ky785428',
#  'Ky785438',
#  'Kx269878',
#  'Ky325476',
#  'Ky325464',
#  'Ky075937',
#  'Ky325482',
#  'Kx922705',
#  'Kx922708',
#  'Ky785459',
#  'Kx838906',
#  'Ky785440',
#  'Ky325474',
#  'Ky785453',
#  'Ky014300',
#  'Ky785432',
#  'Ky785430',
#  'Ky785424',
#  'Vi7',
#  'Mf098765',
#  'Ky785425',
#  'Ky785457',
#  'Ky785443',
#  'Ky075935',
#  'Ky325467',
#  'Ky325481',
#  'Ky785482',
#  'Kx922704',
#  'Kx922706',
#  'Kx922703',
#  'Ky325466',
#  'Ky075939',
#  'Ky325468',
#  'Ky325469',
#  'Ky325480',
#  'Ky325470',
#  'Ky325475',
#  'Ky325478',
#  'Ky325472',
#  'Ky014295',
#  'Ky325483',
#  'Ky325477',
#  'Ky075938',
#  'Ky559003',
#  'Ku729218',
#  'Kx101066',
#  'Kx101060',
#  'Ku940228',
#  'Ku940224',
#  'Kx520666',
#  'Kx101061',
#  'Ku940227',
#  'Kx101065',
#  'Vi36',
#  'Ky559005',
#  'Ky559024',
#  'Ky559008',
#  'Ky559019',
#  'Ky559013',
#  'Ky559009',
#  'Ky559012',
#  'Ky559017',
#  'Ky559011',
#  'Ky559010',
#  'Ky785446',
#  'Kx197205',
#  'Ky785483',
#  'Ky014313',
#  'Ky785427',
#  'Ky014301',
#  'Ky014296',
#  'Ky014320',
#  'Ky014317',
#  'Ky014309',
#  'Ky559031',
#  'Ky559030',
#  'Ku497555',
#  'Ky558995',
#  'Ky559001',
#  'Ky559002',
#  'Ky559022',
#  'Ku991811',
#  'Ky558992',
#  'Ky014307',
#  'Ky559027',
#  'Ky785439',
#  'Ky558997',
#  'Ky785480',
#  'Ky558998',
#  'Ky559015',
#  'Ky558999',
#  'Ky558996',
#  'Kx548902',
#  'Ky317937',
#  'Ky693679',
#  'Ky693678',
#  'Ky075932',
#  'Ky785451',
#  'Ku922960',
#  'Ku647676',
#  'Ky317940',
#  'Ky317938',
#  'Ky317936',
#  'Ky317939',
#  'Kx198135',
#  'Ky785466',
#  'Ky014303',
#  'Ky785477',
#  'Ky785469',
#  'Ky785417',
#  'Ky989971',
#  'Kx156775',
#  'Kx156776',
#  'Kx156774',
#  'Mf574587',
#  'Mf574585',
#  'Kx702400',
#  'Kx247646',
#  'Mf574561',
#  'Mf574565',
#  'Mf574559',
#  'Mf574555',
#  'Mf574571',
#  'Mf574562',
#  'Mf574575',
#  'Mf574576',
#  'Mf574569',
#  'Mf574563',
#  'Mf574564',
#  'Mf574577',
#  'Mf574553',
#  'Mf574552',
#  'Ky693680',
#  'Ky631492',
#  'Ky559020',
#  'Ku365779',
#  'Ku707826',
#  'Ku365777',
#  'Ku365780',
#  'Ku312312',
#  'Ky014297',
#  'Ky785450',
#  'Ku820898',
#  'Vi11',
#  'Kx766028',
#  'Kx056898',
#  'Ku955590',
#  'Mf167360',
#  'Ku365778',
#  'Ky348640',
#  'Ku758877',
#  'Vi4',
#  'Ku937936',
#  'Vi40',
#  'Ky785481',
#  'Ku501215',
#  'Ky075933',
#  'Ky785485',
#  'Ky785436',
#  'Ky075934',
#  'Ky785462',
#  'Ky785464',
#  'Vi23',
#  'Vi39',
#  'Vi30',
#  'Vi32',
#  'Vi37',
#  'Vi12',
#  'Vi1',
#  'Vi2',
#  'Vi35',
#  'Vi25',
#  'Vi27',
#  'Vi43',
#  'Vi34',
#  'Vi13',
#  'Vi38',
#  'Vi3',
#  'Vi5',
#  'Vi21',
#  'Vi6',
#  'Ky559018',
#  'Vi24',
#  'Ky558991',
#  'Ky785410',
#  'Ky785437',
#  'Ky272991',
#  'Ky559032',
#  'Ky014308',
#  'Ky559025',
#  'Ky765326',
#  'Kx906952',
#  'Kx262887',
#  'Kx694534',
#  'Mf098770',
#  'Ky606272',
#  'Ky631493',
#  'Ky631494',
#  'Kx827268',
#  'Kx766029',
#  'Ky648934',
#  'Kx856011',
#  'Mf098771',
#  'Ky120348',
#  'Kx446950',
#  'Kx247632',
#  'Kx446951',
#  'Ky765324',
#  'Mf434518',
#  'Ky328289',
#  'Ky014312',
#  'Ky785452',
#  'Ky014310',
#  'Ky014319',
#  'Mf434521',
#  'Ky765321',
#  'Ky765317',
#  'Ky785442',
#  'Ky785421',
#  'Ky785416',
#  'Ky606273',
#  'Ku501216',
#  'Ku501217',
#  'Ky325479',
#  'Ky325465',
#  'Ky606271',
#  'Mf593625',
#  'Mf159531',
#  'Ky785454',
#  'Ky014315',
#  'Ky785418',
#  'Ky765327',
#  'Ky693677',
#  'Ky785461',
#  'Mf434520',
#  'Ky014327',
#  'Ky014311',
#  'Ky014306',
#  'Ky606274',
#  'Ky785431',
#  'Ku870645',
#  'Ky765320',
#  'Kx421194',
#  'Kx421195',
#  'Ky785444',
#  'Mf434517',
#  'Ky785471',
#  'Mf434522',
#  'Mf434516',
#  'Mf434519',
#  'Ky785448',
#  'Ky785458',
#  'Ky785414',
#  'Ky693676']

# %%
intermediate_node_color='rgb(100,100,100)'

# %% [markdown]
# Node colors (assigned  in `Plotly-rectangular-phylogram-node-colors.ipynb`)

# %%
NA_color={'Cuba': 'rgb(252, 196, 174)',#from cm.Reds color 0.2, ... 0.8
 'Dominican Republic': 'rgb(201, 32, 32)',
 'El Salvador': 'rgb(253, 202, 181)',
 'Guadeloupe': 'rgb(253, 202, 181)',
 'Guatemala': 'rgb(252, 190, 167)',
 'Haiti': 'rgb(252, 145, 114)',
 'Honduras': 'rgb(239, 66, 49)',
 'Jamaica': 'rgb(252, 185, 161)',
 'Martinique': 'rgb(252, 190, 167)',
 'Mexico': 'rgb(247, 109, 82)',
 'Nicaragua': 'rgb(249, 121, 92)',
 'Panama': 'rgb(252, 185, 161)',
 'Puerto Rico': 'rgb(252, 174, 148)',
 'Saint Barthelemy': 'rgb(253, 202, 181)',
 'USA': 'rgb(188, 20, 26)',
 'USVI': 'rgb(206, 36, 34)'}




SAmer_color={'Brazil': 'rgb(21, 127, 59)',# from cm.Greens colors 0.2, 0.4, 0.6, 0.8
 'Colombia': 'rgb(153, 213, 149)',
 'Ecuador': 'rgb(208, 237, 202)',
 'French Guiana': 'rgb(211, 238, 205)',
 'Peru': 'rgb(208, 237, 202)',
 'Suriname': 'rgb(206, 236, 200)',
 'Venezuela': 'rgb(202, 234, 196)'}


SAsia_color={'Singapore': '#0000EE', 'Vietnam': '#1E90FF'}
pl_SAsia=[[0.0, '#1E90FF'], [0.5, '#1E90FF'], [0.5, '#0000EE'], [1.0,'#0000EE' ]]


Oceania_color={'American Samoa': 'rgb(209,95,238)',
 'Fiji': 'rgb(238,130, 238)',
 'French Polynesia': 'rgb(148,0,211)',
 'Tonga': 'rgb(238,130, 238)'}


China_color={'China': 'rgb(255,185,15'} 

JapanKorea_color={'Japan': '#fcdd04'}

# %%
country=[]
region=[]
color=[intermediate_node_color]*len(X)

for k, strain in enumerate(df['Strain']):
   
    i=text.index(strain)
    
    text[i]=text[i]+'<br>Country: '+'{:s}'.format(df.loc[k, 'Country'])+'<br>Region: '+'{:s}'.format(df.loc[k, 'Region'])+\
    '<br>Collection date: '+'{:s}'.format(df.loc[k,'Date'])+\
           '<br>Journal: '+'{:s}'.format(df.loc[k, 'Journal'])+'<br>Authors: '+'{:s}'.format(df.loc[k, 'Authors'])
    country.append(df.loc[k, 'Country'])
    region.append(df.loc[k, 'Region'])
    if df.loc[k, 'Region']=='North America':
        color[i]=NA_color[df.loc[k, 'Country']]
    elif df.loc[k, 'Region']=='South America':
        color[i]=SAmer_color[df.loc[k, 'Country']] 
    elif df.loc[k, 'Region']=='Southeast Asia':
        color[i]=SAsia_color[df.loc[k, 'Country']]
    elif df.loc[k, 'Region']=='Oceania':
        color[i]=Oceania_color[df.loc[k, 'Country']] 
    elif df.loc[k, 'Region']=='China':
        color[i]= '#fecc00'
    elif df.loc[k, 'Region']=='Japan Korea':
        color[i]= '#dc7928'
    else: pass

# %% [markdown]
# Define the Column(s) for the grid to be uploaded to Plotly cloud:

# %%
axis=dict(showline=False,  
          zeroline=False,
          showgrid=False,
          showticklabels=False,
          title='' #y title
          )

# %%
nodes=dict(type='scatter',
           x=X,
           y=Y,
           mode='markers',
           marker=dict(color=color,
                       size=5),
           text=text, #vignet information of each node
           hoverinfo='')

layout=dict(title='Phylogeny of Zika Virus<br>377 genomes colored according to region and country',
            font=dict(family='Balto',size=14),
            width=1000,
            height=3000,
            autosize=False,
            showlegend=False,
            xaxis=dict(showline=True,  
                       zeroline=False,
                       showgrid=False,
                       ticklen=4,          
                       showticklabels=True,
                       title='branch length'),
            yaxis=axis, 
            hovermode='closest',
            shapes=line_shapes,
            plot_bgcolor='rgb(250,250,250)',
            margin=dict(l=10)
           )

# %%
fig=dict(data=[nodes], layout=layout)
iplot(fig)
# Out:
# <div id="d6ff6288-be8f-4bd9-96da-8adbd50e5ba8" style="height: 3000px; width: 1000px;" class="plotly-graph-div"></div><script type="text/javascript">require(["plotly"], function(Plotly) { window.PLOTLYENV=window.PLOTLYENV || {};window.PLOTLYENV.BASE_URL="https://plot.ly";Plotly.newPlot("d6ff6288-be8f-4bd9-96da-8adbd50e5ba8", [{"type": "scatter", "x": [0, 6.555195508771621e-09, 0.005791689352737594, 0.00438466852368986, 0.004942353684003155, 0.005035420108373306, 0.0044775787847450765, 0.004477585339940585, 0.004570489763677347, 0.0049422651635439765, 0.004756347436075718, 0.004384675078885369, 0.004477584553210342, 0.004756363278207898, 0.0045704940275496705, 0.004384681634080878, 0.004570516937643193, 0.0043846881892763865, 0.0044775976636013595, 0.004477604218796868, 0.004570507137940688, 0.004663418463293267, 0.004570513693136197, 0.004384694744471895, 0.004477605089100985, 0.004663442136160482, 0.004477611644296494, 0.004384701299667404, 0.004477630240046842, 0.004570535577754826, 0.00447763679524235, 0.004477643350437859, 0.004477643350437859, 0.004477649905633368, 0.004477649905633368, 0.004384707854862913, 0.004477617481716897, 0.004384714410058422, 0.00447762810896365, 0.0043847209652539305, 0.004384727520449439, 0.004384727520449439, 0.004384734075644948, 0.004384734075644948, 0.004384740630840457, 0.004384740630840457, 0.004384747186035966, 0.004384747186035966, 0.0043847537412314746, 0.0043847537412314746, 0.004384760296426983, 0.004384760296426983, 0.004384766851622492, 0.004384766851622492, 0.0012088403113641886, 0.002417689407026362, 0.001301733356889144, 0.0019523706603379017, 0.001766405933095651, 0.0013017399120846527, 0.0013946328740957975, 0.0018592426197967344, 0.0013946394292913063, 0.0016733918602715176, 0.0013946459844868151, 0.001766306186889093, 0.0015804448941250378, 0.0019523189329635694, 0.002045213482565325, 0.005025903146984859, 0.002788815290330644, 0.003347526943494409, 0.0033475334986899177, 0.003440431594245871, 0.0038121462050035126, 0.003719194122191927, 0.0038120982913291204, 0.003812098925493441, 0.0038121054806889497, 0.003997922989289412, 0.003905014024618623, 0.003997925051686169, 0.003997925769478311, 0.0039979248991065825, 0.003997922989289412, 0.003997929544484921, 0.003997929544484921, 0.004369716152512725, 0.0043697227077082335, 0.0043697227077082335, 0.003997936099680429, 0.003997942654875938, 0.003997942654875938, 0.0013946256848911785, 0.0022315226251980527, 0.0019522082524871284, 0.0014875172264353163, 0.0018591735833402147, 0.0015804086844372612, 0.0014875173789306501, 0.0016733154913112292, 0.0016733142212756406, 0.0016733507353717523, 0.002045040061474638, 0.0019520786172473534, 0.0019520786172473534, 0.002509703207316023, 0.0033463947305382487, 0.0027884207214996745, 0.0027884272766951833, 0.0032530202948781164, 0.003253026850073625, 0.003345918742532306, 0.0033459252977278147, 0.003531719394911894, 0.003624652344309757, 0.0045550286689896875, 0.00464793962197412, 0.004647939705528881, 0.00464794626072439, 0.00464794626072439, 0.004647952815919899, 0.004647952815919899, 0.002044972051249887, 0.004373527650117375, 0.0022307722131347375, 0.0022307787683302463, 0.0029743646838081366, 0.0023236714158571667, 0.003626022063752644, 0.0037189033754402197, 0.003904715867636001, 0.0023236779710526755, 0.0026953566485403476, 0.0031603496747214612, 0.00316035622991697, 0.0036250056314946237, 0.002323665730684382, 0.002416560034625468, 0.004184173813866531, 0.003998072747637807, 0.0025094674945695707, 0.0039047048364586998, 0.0026023610121426568, 0.002881087449966677, 0.002695254529692301, 0.00269526108488781, 0.002973989461241487, 0.004370123499600677, 0.0030669280357455203, 0.003066934590941029, 0.0031598315052091307, 0.0035315768230369986, 0.003717578174230825, 0.003717584729426334, 0.004461304275291323, 0.004182288699216915, 0.0038104787841072136, 0.004461103106365956, 0.004646919234193448, 0.004646926119245454, 0.004739821455414164, 0.005390422154220745, 0.004739828010609673, 0.0046 ...
